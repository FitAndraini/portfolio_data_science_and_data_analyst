# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("https://raw.githubusercontent.com/FitAndraini/portfolio_data_science_and_data_analyst/master/Dataset/hotel_bookings_data.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  adults  ...  \
# 0                        0                         0       2  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# melihat deskripsi statistik dari dataframe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2018.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2017.000000
# 25%         0.000000      18.000000        2018.000000
# 50%         0.000000      69.000000        2018.000000
# 75%         1.000000     160.000000        2019.000000
# max         1.000000     737.000000        2019.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Melihat jumlah data
for col in df:
    print(f'''Value count kolom {col}:''')
    print(df[col].value_counts())
    print()
# Out:
# Value count kolom hotel:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64
#
# Value count kolom is_canceled:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64
#
# Value count kolom lead_time:
# 0      6345
# 1      3460
# 2      2069
# 3      1816
# 4      1715
#        ...
# 400       1
# 370       1
# 532       1
# 371       1
# 463       1
# Name: lead_time, Length: 479, dtype: int64
#
# Value count kolom arrival_date_year:
# 2018    56707
# 2019    40687
# 2017    21996
# Name: arrival_date_year, dtype: int64
#
# Value count kolom arrival_date_month:
# October      13877
# September    12661
# July         11791
# December     11160
# June         11089
# August       10939
# November     10508
# May           9794
# April         8068
# January       6794
# February      6780
# March         5929
# Name: arrival_date_month, dtype: int64
#
# Value count kolom arrival_date_week_number:
# 33    3580
# 30    3087
# 32    3045
# 34    3040
# ...

# %% [markdown]
# Kesimpulan:
# - Sudah memiliki type data yang sesuai

# %% [markdown]
# # TASK 1 (WEEK 1)

# %% [markdown]
# ### Mengatasi data null

# %%
# Mengecek data NULL
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_weekdays_nights               0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# city                                 488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# ...

# %%
## Terdapat 4 kolom yang memiliki null ##

# Kolom Children dapat kita isi dengan angka 0 menggambarkan tidak adanya anak dalam data pemesanan hotel
df['children'] = df['children'].fillna(0)

# Kolom city dapat kita isi dengan "unknown" karena tidak diketahui negara asal dari pemesan hotel
df['city'] = df['city'].fillna('unknown')

# Kolom agent dan company dapat kita isi juga dengan angka 0 sebagai "undefined" value, mengapa angka 0? karena pada agent dan company tidak terdapat angka 0 (minimum value agent: 1, maksimum value company: 6)
df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_weekdays_nights          0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# city                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# Mengisi data NULL
#df['city'].fillna(df['city'].mode()[0], inplace=True)
#df['agent'].fillna(df['agent'].mean(), inplace=True)
#df['company'].fillna(df['company'].mean(), inplace=True)
#df['children'].fillna(df['children'].mean(), inplace=True)

# %% [markdown]
# ### Mengganti value yang tidak sesuai (Hint: Perhatikan kolom "meal")

# %%
df["meal"].value_counts()
# Out:
# Breakfast     92310
# Dinner        14463
# No Meal       10650
# Undefined      1169
# Full Board      798
# Name: meal, dtype: int64

# %%
# data "meal" mengandung value "Undefined", yang sebetulnya sama dengan "No Meal"

df['meal'] = df['meal'].replace('Undefined', 'No Meal')
df["meal"].value_counts()
# Out:
# Breakfast     92310
# Dinner        14463
# No Meal       11819
# Full Board      798
# Name: meal, dtype: int64

# %%
df['children'].value_counts()
# Out:
# 0.0     110800
# 1.0       4861
# 2.0       3652
# 3.0         76
# 10.0         1
# Name: children, dtype: int64

# %% [markdown]
# ### Membuang data yang tidak diperlukan (Hint: Perhatikan total jumlah tamu untuk setiap pemesanan)

# %% [markdown]
# Terdapat data **adults**, **children** dan **babies** yang tergolong sebagai tamu, sehingga perlu dilakukan SUM dari ketiga data tersebut untuk melihat total tamu

# %%
# Membuat data total guest yaitu jumlah dari adults, children, dan babies
df["guest"] = df["adults"]+df["children"]+df["babies"]

# %%
df["guest"].value_counts()
# Out:
# 2.0     82051
# 1.0     22581
# 3.0     10495
# 4.0      3929
# 0.0       180
# 5.0       137
# 26.0        5
# 12.0        2
# 27.0        2
# 20.0        2
# 10.0        2
# 40.0        1
# 50.0        1
# 55.0        1
# 6.0         1
# Name: guest, dtype: int64

# %%
# Hapus kolom 'adults', 'children', dan 'babies' karena sudah dilakukan pengelompokan data di kolom 'guest'
df.drop(['adults','children','babies'], axis=1, inplace=True)

# %% [markdown]
# Terdapat data 0 sebanyak 180 di kolom `guest`, sehingga perlu dilakukan penghapusan

# %%
# Kita akan hapus data yang memiliki 0 guest
df_pros = df[df["guest"] > 0].copy()

# %%
print("before pre-processing: ", df.shape[0])
print("after pre-processing: ", df_pros.shape[0])
# Out:
# before pre-processing:  119390
# after pre-processing:  119210

# %%
df_pros['arrival_date_year'].unique()
# Out:
# array([2017, 2018, 2019])

# %%
df_pros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119210 entries, 0 to 119389
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119210 non-null  object
#  1   is_canceled                     119210 non-null  int64
#  2   lead_time                       119210 non-null  int64
#  3   arrival_date_year               119210 non-null  int64
#  4   arrival_date_month              119210 non-null  object
#  5   arrival_date_week_number        119210 non-null  int64
#  6   arrival_date_day_of_month       119210 non-null  int64
#  7   stays_in_weekend_nights         119210 non-null  int64
#  8   stays_in_weekdays_nights        119210 non-null  int64
#  9   meal                            119210 non-null  object
#  10  city                            119210 non-null  object
#  11  market_segment                  119210 non-null  object
# ...

# %% [markdown]
# # TASK 2 (WEEK 2)

# %% [markdown]
# # Buatlah tabel agregat yang menunjukan perbandingan jumlah pemesanan hotel setiap bulannya berdasarkan jenis hotel

# %%
df1 = df_pros.copy()

# %%
# Membuat data agregasi untuk menghitung jumlah pemesanan hotel per bulan berdasarkan tipe hotel
df1 = df1.groupby(['hotel', 'arrival_date_month'])['arrival_date_year'].agg(['nunique', 'count']).reset_index()
df1.columns = ['type_hotel', 'month', 'unique_year', 'jumlah_booking'] # mengubah nama kolom tabel
df1
# Out:
#       type_hotel      month  unique_year  jumlah_booking
# 0     City Hotel      April            2            4950
# 1     City Hotel     August            2            7885
# 2     City Hotel   December            2            7594
# 3     City Hotel   February            2            4114
# 4     City Hotel    January            2            4336
# 5     City Hotel       July            2            8221
# 6     City Hotel       June            2            7469
# 7     City Hotel      March            2            3730
# 8     City Hotel        May            2            6434
# 9     City Hotel   November            2            7392
# 10    City Hotel    October            3            8967
# 11    City Hotel  September            3            8071
# 12  Resort Hotel      April            2            3102
# 13  Resort Hotel     August            2            3044
# 14  Resort Hotel   December            2            3553
# ...

# %% [markdown]
# Perhatikan data bulan October dan September diambil dari data 3 tahun lalu, sedangkan bulan-bulan lain hanya diambil dari data 2 tahun lalu, perlu dilakukan normalisasi agar perbandingannya sesuai

# %%
# normalisasi untuk mendapatkan jumlah rata-rata pemesanan di suatu bulan pada tahun yang berbeda
df1['average_jumlah_booking'] = round(df1['jumlah_booking']/df1['unique_year'])
df1
# Out:
#       type_hotel      month  unique_year  jumlah_booking  \
# 0     City Hotel      April            2            4950
# 1     City Hotel     August            2            7885
# 2     City Hotel   December            2            7594
# 3     City Hotel   February            2            4114
# 4     City Hotel    January            2            4336
# 5     City Hotel       July            2            8221
# 6     City Hotel       June            2            7469
# 7     City Hotel      March            2            3730
# 8     City Hotel        May            2            6434
# 9     City Hotel   November            2            7392
# 10    City Hotel    October            3            8967
# 11    City Hotel  September            3            8071
# 12  Resort Hotel      April            2            3102
# 13  Resort Hotel     August            2            3044
# 14  Resort Hotel   December            2            3553
# ...

# %% [markdown]
# Perlu dilakukan penulisan nama bulan disingkat, untuk mempermudah visualisasi. Oleh karena itu, dibuat kolom baru yang berisi singkatan dari nama bulan yakni 3 huruf pertama dari nama bulan

# %%
# Membuat singkatan nama bulan agar lebih mudah divisualisasi
ordered_months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                  "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df1["month"] = df1["month"].str[:3] # mengambil 3 huruf terdepan dari setiap bulan
df1["month"] = pd.Categorical(df1["month"], categories=ordered_months, ordered=True) # mengurutkan bulan

df1.head()
# Out:
#    type_hotel month  unique_year  jumlah_booking  average_jumlah_booking
# 0  City Hotel   Apr            2            4950                  2475.0
# 1  City Hotel   Aug            2            7885                  3942.0
# 2  City Hotel   Dec            2            7594                  3797.0
# 3  City Hotel   Feb            2            4114                  2057.0
# 4  City Hotel   Jan            2            4336                  2168.0

# %%
plt.figure(figsize=(15,10)) # mengatur ukuran figure
daftar_warna_custom = ['blue', 'red']
sns.lineplot(x='month', y='average_jumlah_booking', hue='type_hotel',
             size="type_hotel", sizes=(2.5, 2.5), palette=daftar_warna_custom, data=df1) # plot awal menggunakan lineplot dari library seaborn

plt.xlabel('Visitor Arrivals per Month', fontsize=15) # mengatur title pada x-axis
plt.ylabel('Average Hotel Booking', fontsize=15) # mengatur title pada y-axis
plt.ylim(0, 4800) # membatasi y axis

plt.tick_params(axis='both', which='major', labelsize=14) # memperbesar ukuran x-y axis label
plt.grid() # menambahkan gridline
plt.legend(title='Type Hotel', title_fontsize=15, prop={'size':13}) # mengatur judul dan ukuran font pada legenda

plt.axvline(4, ls='--', color='green') # membuat garis vertikal untuk menghighlight insight
plt.axvline(6, ls='--', color='green') # membuat garis vertikal untuk menghighlight insight
plt.text(x=4.5, y=4400, s='Holiday \nSeason', fontsize=16, color='green') # menambahkan teks keterangan
plt.stackplot(np.arange(4,7,1), [[4800]], color='green', alpha=0.3) # memberikan blok warna pada area yang dihighlight 2 garis vertikal

plt.axvline(9, ls='--', color='green') # membuat garis vertikal untuk menghighlight insight
plt.axvline(11, ls='--', color='green') # membuat garis vertikal untuk menghighlight insight
plt.text(x=9.5, y=4400, s='Holiday \nSeason', fontsize=16, color='green') # menambahkan teks keterangan
plt.stackplot(np.arange(9,12,1), [[4800]], color='green', alpha=0.3) # memberikan blok warna pada

plt.text(x=1.2, y=5000, s="Types of Hotels that are mostly visited during the holidays",
         fontsize=20, fontweight='bold') # memberikan judul yang informatif
#plt.text(x=-0.5, y=4850, s="City Hotel has the decreased guests in August and September, while both hotels have less \ncustomer during not holiday season (Jan-Mar)",
         #fontsize=18) # memberikan keterangan tambahan atas judul

plt.tight_layout() # mengatur layout dari visualisasi agar tidak terpotong
#plt.savefig('D:/Mini Project Visualisasi/investigate_hotel_business.png', dpi=200)
#plt.savefig('document/investigate_hotel_business.png', dpi=200); # menyimpan gambar

# %% [markdown]
# ## **Insight**

# %% [markdown]
# - Kedua jenis hotel mendapatkan booking terbanyak sekitar bulan Juni dan July. Bisa terjadi bahwa pada bulan-bulan tersebut merupakan hari libur.
# - Kemudian pada bulan Aug-Sep mengalami penurunan yang cukup jauh. Sehingga untuk hotel-hotel wilayah perkotaan mengalami penurunan yang sangat signifikan.
# - Kemudian disusul lagi pada bulan Oct-Desc mengalami kenaikan lagi untuk jenis hotel perkotaan, bisa saja pada bulan tersebut bertepatan dengan libur anak sekolah.
# - **Artinya Pengunjung akan banyak booking hotel pada hari libur**
# - **Kenaikan booking hotel pada hari libur yang sangat drastis terjadi untuk jenis City Hotel, Artinya customer lebih senang untuk berlibur kewilayah perkotaan**

# %% [markdown]
# # TASK 3 (WEEK 3)

# %% [markdown]
# # Analisa Pengaruh Durasi Menginap terhadap tingkat Pembatalan Pemesanan Hotel

# %%
df2 = df_pros.copy()

# %%
# Melakukan agregasi data untuk mendapatkan durasi menginap berdasarkan jenis hotel
df2["total_stay_the_night"] = df2["stays_in_weekend_nights"] + df2["stays_in_weekdays_nights"] # mencari total malam yang dipesan

# %%
# Perlu dilakukan drop terhadap kolom 'stays_in_weekend_nights' dan 'stays_in_weekdays_nights' karena sudah didapatkan total malam menginap
df2.drop(['stays_in_weekend_nights', 'stays_in_weekdays_nights'], axis=1, inplace=True)

# %%
sns.histplot(data=df2, x="total_stay_the_night", binwidth=5, color="green")
# Out:
# <Axes: xlabel='total_stay_the_night', ylabel='Count'>

# %%
df2["total_stay_the_night"].value_counts()
# Out:
# 2     27632
# 3     27064
# 1     21005
# 4     17373
# 7      8648
# 5      7771
# 6      3846
# 8      1155
# 10     1135
# 14      913
# 9       840
# 0       645
# 11      393
# 12      220
# 13      141
# 15       72
# 21       71
# 16       40
# 25       37
# 18       35
# 28       34
# 19       22
# 17       20
# 20       14
# 22       13
# 29       13
# 30       13
# 23        8
# 26        6
# 24        6
# 35        5
# 42        4
# 27        4
# 33        3
# 56        2
# 38        1
# 48        1
# 46        1
# 45        1
# 69        1
# 60        1
# 34        1
# Name: total_stay_the_night, dtype: int64

# %% [markdown]
# Berdasarkan pada histogram di atas, dapat dilihat bahwa persebaran data terlihat right-skewed. Oleh karena itu dilakukan pengelompokkan untuk membuat persebarannya menjadi lebih merata. Pengelompokkan yang dilakukan untuk total jumlah malam lebih besar dari 21 akan dikelompokkan menjadi 21, total malam (15-21) akan dikelompokkan menjadi 15.

# %%
# pengelompokkan data berdasarkan hasil pengamatan distribusi data
df2['total_stay_nights_group'] = np.where(df2['total_stay_the_night'] > 21, 21,
                                       np.where(df2['total_stay_the_night'] > 14, 15, df2['total_stay_the_night']))
df2['total_stay_nights_group'].value_counts()
# Out:
# 2     27632
# 3     27064
# 1     21005
# 4     17373
# 7      8648
# 5      7771
# 6      3846
# 8      1155
# 10     1135
# 14      913
# 9       840
# 0       645
# 11      393
# 15      274
# 12      220
# 21      155
# 13      141
# Name: total_stay_nights_group, dtype: int64

# %%
# membuat tabel agregat
df2 = df2.groupby(['hotel', 'is_canceled', 'total_stay_nights_group'])['arrival_date_month'].count().reset_index(name='num_bookings')
df2 = df2.pivot_table(index=['hotel', 'total_stay_nights_group'], columns='is_canceled', values='num_bookings').reset_index()
df2['pct_canceled'] = round(df2[1]*100.0/(df2[0]+df2[1]), 2) # mencari persentase pembatalan (cancellation) untuk setiap kombinasi 'hotel' dan 'total_stay_nights_group'

df2
# Out:
# is_canceled         hotel  total_stay_nights_group      0      1  pct_canceled
# 0              City Hotel                        0    251     13          4.92
# 1              City Hotel                        1   9155   4103         30.95
# 2              City Hotel                        2  10983  10432         48.71
# 3              City Hotel                        3  11889   9482         44.37
# 4              City Hotel                        4   7694   4853         38.68
# 5              City Hotel                        5   3210   1775         35.61
# 6              City Hotel                        6   1111    938         45.78
# 7              City Hotel                        7   1245    808         39.36
# 8              City Hotel                        8    205    176         46.19
# 9              City Hotel                        9    119     93         43.87
# 10             City Hotel                       10     80    116         59.18
# ...

# %% [markdown]
# Tujuan dari plot yang ingin ditampilkan adalah untuk membandingkan 2 tipe hotel terhadap durasi menginapnya pelanggan, sehingga digunakan diagram batang untuk melihat tingkat pembatalan pemesanan hotel. Selain itu, kita akan melihat bagaimana durasi menginap memengaruhi tingkat pembatalan pemesanan hotel, sehingga tren untuk data tersebut ikut ditampilkan pula

# %%
daftar_warna_custom = ['green', 'orange']

plt.figure(figsize=(15,10))
sns.regplot(x='total_stay_nights_group', y='pct_canceled', data=df2[df2['hotel'] == 'City Hotel'], scatter=False, label='Trend City Hotel', color='green')
sns.regplot(x='total_stay_nights_group', y='pct_canceled', data=df2[df2['hotel'] == 'Resort Hotel'], scatter=False, label='Trend Resort Hotel', color='orange')
sns.barplot(x='total_stay_nights_group', y='pct_canceled', hue='hotel', palette=daftar_warna_custom, data=df2, alpha=0.75)

plt.tick_params(axis='both', which='major', labelsize=14) # memperbesar ukuran x-y axis label
plt.grid() # menambahkan gridline
plt.legend(title='Hotel Type', title_fontsize=15, prop={'size':13}) # mengatur judul dan ukuran font pada legenda

plt.xticks(range(0,17,1), labels=[str(x) for x in range(0,15,1)]+["15-21",">21"]) # mengatur customized-label pada x-axis
plt.xlabel('Total Nights Booked', fontsize=15) # mengatur title pada x-axis
plt.ylabel('Percentage of Booking Canceled (%)', fontsize=15) # mengatur title pada y-axis
plt.ylim(0, 100) # membatasi y axis
plt.xlim(0.5, 16.5) # membatasi x axis

plt.text(x=2, y=105, s="Positive Trend on Total Nights and Percentage of Booking Canceled",
         fontsize=20, fontweight='bold') # memberikan judul yang informatif

plt.tight_layout() # mengatur layout dari visualisasi agar tidak terpotong
#plt.savefig('fig/investigate_hotel_business_v02.png', dpi=200); # menyimpan gambar

# %% [markdown]
# ## **Insight**

# %% [markdown]
# - Semakin lama total malam pemesanan hotel(durasi menginap), maka semakin tinggi persentase pemesanan dibatalkan.
# - City Hotel memiliki tren yang lebih curam (signifikan)dibandingkan dengan Resort Hotel, Artinya kemungkinan persentase pembatalan pemesanan untuk jenis City Hotel lebih banyak terjadi dibandingkan Resort Hotel.

# %% [markdown]
# # TASK 4 (WEEK 4)

# %% [markdown]
# # Analisis Pengaruh Jarak waktu Pemesanan terhadap Tingkat Pembatalan Pemesanan Hotel

# %%
# Melakukan copy pada data hasil pre-processing
df3 = df_pros.copy()

# %%
sns.histplot(data=df3, x="lead_time", bins=50, color="GREEN")
# Out:
# <Axes: xlabel='lead_time', ylabel='Count'>

# %% [markdown]
# Persebaran data terlihat right-skewed. Oleh karena itu dilakukan pengelompokkan untuk membuat persebarannya menjadi lebih merata. Jarak waktu pemesanan yang mulanya dalam satuan harian, dikelompokkan menjadi satuan bulanan yakni per 30 hari.

# %%
# Mengkategorisasi kolom lead_time agar lebih sederhana
df3['lead_times'] = np.where(df3['lead_time'] > 400, 401, df3['lead_time']) # lead_time dengan value yg cukup besar (lebih dari 400) dikategorisasikan menjadi satu grup

bins = list(np.arange(0,max(df3['lead_times'])+30, 30))
labels = ["{0}-{1}".format(str(bins[x]), str(bins[x+1])) for x in range(len(bins[:-1]))]
df3['lead_time_group'] = pd.cut(df3['lead_times'],bins=bins, include_lowest=True, labels=labels) # groupping lead_time untuk setiap kelipatan 30

# %%
# melakukan agregasi data untuk menghitung jumlah pemesanan berdasarkan group lead_time yang sudah dibuat dan berdasarkan tipe hotel
df3_book = df3.groupby(['hotel','lead_time_group', 'is_canceled'])['hotel'].count().reset_index(name='num_bookings')
df3_pivot = df3_book.pivot_table(index=['hotel','lead_time_group'], columns='is_canceled', values='num_bookings').reset_index()
df3_pivot.columns = ['hotel_type','lead_time_group', 'not_canceled', 'canceled']
df3_pivot['all_bookings'] = df3_pivot['not_canceled']+df3_pivot['canceled']
df3_pivot['pct_canceled'] = df3_pivot['canceled']*100.0/(df3_pivot['all_bookings'])

df3_pivot.head()
# Out:
#    hotel_type lead_time_group  not_canceled  canceled  all_bookings  \
# 0  City Hotel            0-30         18060      5184         23244
# 1  City Hotel           30-60          7266      4608         11874
# 2  City Hotel           60-90          5210      3692          8902
# 3  City Hotel          90-120          3956      3486          7442
# 4  City Hotel         120-150          3064      2542          5606
#
#    pct_canceled
# 0     22.302530
# 1     38.807479
# 2     41.473826
# 3     46.842247
# 4     45.344274

# %%
daftar_warna_custom = ['firebrick', 'orange']

plt.figure(figsize=(15,10)) # mengatur ukuran figure
sns.barplot(x='lead_time_group', y='pct_canceled', hue='hotel_type', data=df3_pivot, palette=daftar_warna_custom) # plot awal menggunakan barplot dari library seaborn

plt.tick_params(axis='both', which='major', labelsize=12) # memperbesar ukuran x-y axis label
plt.grid() # menambahkan gridline
plt.legend(title='Hotel Type', title_fontsize=14, prop={'size':12}, loc=9) # mengatur judul dan ukuran font pada legenda

plt.xlabel('Lead Time Groups (by 30 days)', fontsize=14) # mengatur title pada x-axis
plt.ylabel('Percentage of Booking Canceled (%)', fontsize=14) # mengatur title pada y-axis
plt.ylim(0, 100) # membatasi y-axis
plt.xlim(-0.5,13.5) # membatasi x-axis

plt.axvline(0.5, ls='--', color='black') # membuat garis vertikal untuk menghighlight insight
plt.text(x=-0.2, y=80, s='1 Month', fontsize=18, color='black', fontweight='bold', rotation=90) # menambahkan teks keterangan
plt.stackplot(np.arange(-0.5,1.5,1), [[100]], color='yellowgreen', alpha=0.3) # memberikan blok warna pada area yang dihighlight 2 garis vertikal

plt.axvline(8.5, ls='--', color='black') # membuat garis vertikal untuk menghighlight insight
plt.text(x=10, y=90, s='Around 1 Year', fontsize=18, color='black', fontweight='bold') # menambahkan teks keterangan
plt.stackplot(np.arange(8.5,14.5,1), [[100]], color='yellowgreen', alpha=0.3) # memberikan blok warna pada area yang dihighlight 2 garis vertikal

plt.text(x=1, y=105, s="Trend of Lead Time and Percentage of Booking Canceled (%)",
         fontsize=20, fontweight='bold') # memberikan judul yang informatif
#plt.text(x=-0.5, y=102, s="(Jarak Waktu Pemesanan Hotel Hingga Waktu Kedatangan) dan Tingkat Pembatalan Pemesanan Hotel.",
         #fontsize=20, fontweight='bold') # memberikan keterangan tambahan atas judul

plt.tight_layout() # mengatur layout dari visualisasi agar tidak terpotong
#plt.savefig('fig/investigate_hotel_business_v03.png', dpi=200); # menyimpan gambar

# %% [markdown]
# ## **Insight**
# - Analisis ini berfokus untuk melihat trend atau korelasi antara waktu tunggu (jarak waktu pemesanan hotel hingga waktu kedatangan) dan tingkat pembatalan pemesanan hotel.
# - Percentage pembatalan pemesanan hotel paling rendah ada pada pemesanan yang memiliki waktu tunggu kurang dari 30 hari untuk jenis **City Hotel** dan **Resort Hotel**.
# - Jenis **City Hotel** mengalami pembatalan pemesanan lebih banyak dalam jangka waktu tunggu sekitar 1 tahun dibanding waktu tunggu yang lebih rendah.
